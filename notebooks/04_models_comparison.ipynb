# %%
import pandas as pd

metrics = pd.read_csv("../reports/metrics.csv")

# %%
metrics.head()
# Out:
#                              run_id              model         pipeline  \
# 0  aeeb95464a0045a5bb3d491cea8f3ce0  gradient_boosting    tree_pipeline
# 1  f528a235bb014cdda7a9310f9eab1bf6      random_forest    tree_pipeline
# 2  3742ce019ba442deab396d2b195dc251  linear_regression  linear_pipeline
#
#     cv_rmse      rmse       mae        r2  \
# 0  0.481008  0.476900  0.318324  0.826441
# 1  0.509243  0.503917  0.326365  0.806219
# 2       NaN  0.683267  0.493417  0.643734
#
#                                          best_params
# 0  {"learning_rate": 0.12973169683940733, "max_de...
# 1  {"max_depth": 30, "min_samples_leaf": 2, "min_...
# 2  {"copy_X": true, "fit_intercept": true, "n_job...
